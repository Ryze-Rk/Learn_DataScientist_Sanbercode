# %% [markdown]
# # List

# %%
peserta = {
    'Data science' : {'peserta' : 300, 'peserta_1' : 100, 'peserta_2' : 200},
    'UI/UX design' : {'peserta' : 220, 'peserta_1' : 100, 'peserta_2' : 120},
    'Agile development' : {'peserta' : 175, 'peserta_1' : 90, 'peserta_2' : 85},
    'Laravel development' : {'peserta' : 250, 'peserta_1' : 100, 'peserta_2' : 150},
    'Wordpress' : {'peserta' : 150, 'peserta_1' : 75, 'peserta_2' : 75}
}

def sanbercode(a):
  for k,v, in a.items():
    print('jumlah peserta {0} adalah {1} laki2 dan {2} perempuan' .format(k,v['peserta_2'],v['peserta_1']))

sanbercode(peserta)
# Out:
# jumlah peserta Data science adalah 200 laki2 dan 100 perempuan
# jumlah peserta UI/UX design adalah 120 laki2 dan 100 perempuan
# jumlah peserta Agile development adalah 85 laki2 dan 90 perempuan
# jumlah peserta Laravel development adalah 150 laki2 dan 100 perempuan
# jumlah peserta Wordpress adalah 75 laki2 dan 75 perempuan

# %%
List1 = [1,2,3,4,5]
List2 = [6,7,8,9,10]
#List2 = list(List1)
#List2 = List1[ : ]
#List2 = List1.copy()
#List2.copy() = List1
#List2 = List1 
#List2 = list(List1)
#List2 = List1
#List2.copy() = List1
List2
# Out:
# [1, 2, 3, 4, 5]

# %%
mainan = ['uno','remi','catur','monopoli','ludo']

def gaskeun():
  del mainan[0:1]
  return mainan
print(gaskeun())
# Out:
# ['remi', 'catur', 'monopoli', 'ludo']

# %%
list1 = ['raka@gmail.com', 'yudi@gmail.com']
list2 = ['raka@gmail.com', 'yuda@gmail.com']
#list_new = [i for i in list1 and i in list2]
#list_new = [i for i in list1 and if in list2]
#list_new = [i for i in list1 if i in list2] #True
#list_new = [i for i in list2 and list1]
#list_new = [i for i in list1 and list2]
print(list_new)
# Out:
# ['raka@gmail.com', 'yudi@gmail.com']

# %% [markdown]
# <h2>Soal 1: Sifat List</h2>
#
# Jawab Pertanyaan di bawah ini:
#
# Jenis data apa saja yang bisa ada di dalam List?

# %% [markdown]
# **Jawaban:**
#
# **Jenis data yang bisa dimasukan didalam List bisa berupa numeric, string, float, integer, boolean, dan lain-lain yang membuatnya heterogen. Hal ini menandakan bahwa list dapat memiliki semua jenis data dan dapat diulangi daftar data yang dimasukan di list menggunakan jenis loop apa pun.**

# %% [markdown]
# <h2>Soal 2: Akses List</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
a = ['1', '13b', 'aa1', 1.32, 22.1, 2.34]
# slicing list
print(a[1:5])
# Out:
# ['13b', 'aa1', 1.32, 22.1]

# %% [markdown]
# Expected Output :
#
# [ '13b', 'aa1', 1.32, 22.1 ]

# %% [markdown]
# <h2>Soal 3: Nested List</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
a = [1.32, 22.1, 2.34]
b = ['1', '13b', 'aa1']
c = [3, 40, 100]
# combine list
print([a, c, b])
# Out:
# [[1.32, 22.1, 2.34], [3, 40, 100], ['1', '13b', 'aa1']]

# %% [markdown]
# Expected Output :
#
# [ [1.32, 22.1, 2.34], [3, 40, 100], ['1', '13b', 'aa1'] ]

# %% [markdown]
# <h2>Soal 4: Akses Nested List</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
a = [
    [5, 9, 8],
    [0, 0, 6]
    ]
# subsetting list
print(a[1][-2:])
# Out:
# [0, 6]

# %% [markdown]
# Expected Output :
#
#
# [0, 6]

# %% [markdown]
# <h2>Soal 5: Built in Function List</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
p = [0, 5, 2, 10, 4, 9]
# ordered list
print(sorted(p, reverse=False))
# get max value of list
print(max(p))
# Out:
# [0, 2, 4, 5, 9, 10]
# 10

# %% [markdown]
# Expected Output :
#
# [0, 2, 4, 5, 9, 10]
#
# 10

# %% [markdown]
# <h2>Soal 6: List Operation</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
a = [1, 3, 5]
b = [5, 1, 3]
# combine list
b+a
# Out:
# [5, 1, 3, 1, 3, 5]

# %% [markdown]
# Expected Output :
#
# [5, 1, 3, 1, 3, 5]

# %% [markdown]
# <h2>Soal 7: List Manipulation</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
a = [
    [5, 9, 8],
    [0, 0, 6]
    ]
# change list value
a[0][2] = 10
# change list value
a[1][0] = 11
print(a)
# Out:
# [[5, 9, 10], [11, 0, 6]]

# %% [markdown]
# Expected Output :
#
# [ [5, 9, 10], [11, 0, 6] ]

# %% [markdown]
# <h2>Soal 8: Delete Element List</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
areas = ["hallway", 11.25, "kitchen", 18.0,
        "chill zone", 20.0, "bedroom", 10.75,
         "bathroom", 10.50, "poolhouse", 24.5,
         "garage", 15.45]

# Hilangkan elemen yang bernilai "bathroom" dan 10.50 dalam satu statement code
del(areas[8:10])
print(areas)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'poolhouse', 24.5, 'garage', 15.45]

# %% [markdown]
# Expected Output:
#
# ['hallway',
#  11.25,
#  'kitchen',
#  18.0,
#  'chill zone',
#  20.0,
#  'bedroom',
#  10.75,
#  'poolhouse',
#  24.5,
#  'garage',
#  15.45]

# %% [markdown]
# ## Soal 9: List Comprehension
#
# Gunakan metode **list comprehension** untuk mencari anggota dari S yang habis di bagi 2, kemudian assign hasilnya dalam bentuk list ke dalam variabel T.

# %%
S = [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

T = [i for i in S if i % 2==0]

print(T)
# Out:
# [0, 4, 16, 36, 64]

# %% [markdown]
# Expected Output:
#
# [0, 4, 16, 36, 64]

# %% [markdown]
# # Dictionary

# %% [markdown]
# <h2>Soal 10: Akses Dictionary</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# print semua key yang ada di objek europe
print(europe.keys())
# print nilai dari key franche
print(europe['france'])
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])
# paris

# %% [markdown]
# Expected Output:
#
# dict_keys(['spain', 'france', 'germany', 'norway'])
#
# paris

# %% [markdown]
# <h2>Soal 11: Menambahkan key-value baru ke Dictionary</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# tambahkan key itali ke objek dictionary dengan value roma
europe ['itali'] = 'roma'

print('=== Check dict europe ===')
print(europe)

# cek apakah itali ada di dalam objek dictionary
print ('Expected Output:')
print('itali' in europe)
# Out:
# === Check dict europe ===
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'itali': 'roma'}
# Expected Output:
# True

# %% [markdown]
# Expected Output:
#
# True

# %% [markdown]
# <h2>Soal 12: Update dan Remove Dictinary</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
europe = {'spain':'madrid', 'france':'paris', 'germany':'bonn',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw',
          'australia':'vienna' }

# update nilai ibukota german ke berlin
europe ['germany'] = 'berlin'

# remove australia dari europa
europe.pop('australia') # bisa juga menggunakan del europe ['australia]

print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %% [markdown]
# Expected Output:
#
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %% [markdown]
# <h2>Soal 13: Nested Dictionary</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
country = { 
           'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } 
         }

# berapa populasi dari kota german?
print(country['germany']['population'])

# update data baru, yaitu negara indonesia dengan capital jakarta dan poulasi 250
country['indonesia'] = {'capital': 'jakarta', 'population' :250}

print(country)
# Out:
# 80.62
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'indonesia': {'capital': 'jakarta', 'population': 250}}

# %% [markdown]
# Expected Output:
#
# 80.62
#
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'indonesia': {'capital': 'jakarta', 'population': 250}}

# %% [markdown]
# <h2>Soal 14: Loop Dictionary</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
country = { 
           'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 },
           'indonesia' : {'capital':'jakarta', 'population':250}
         }

for key in country:
    Daerah = country[key]['capital']
    print('Ibukota '+ key +' adalah '+ Daerah)
# Out:
# Ibukota spain adalah madrid
# Ibukota france adalah paris
# Ibukota germany adalah berlin
# Ibukota norway adalah oslo
# Ibukota indonesia adalah jakarta

# %% [markdown]
# Expected Output:
#
# Ibukota spain adalah madrid
#
# Ibukota france adalah paris
#
# Ibukota germany adalah berlin
#
# Ibukota norway adalah oslo
#
# Ibukota indonesia adalah jakarta
